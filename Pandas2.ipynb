# %% [markdown]
# <a href="https://colab.research.google.com/github/lelialealgondim-ux/gti-modulo1/blob/main/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io

# %%
import pandas as pd

# %%
# @title Texto de título padrão
variable_name = ""
pd.read_csv(io.StringIO('''num ,nome,nota
1,Ana,11.2
2,Bruno,20.3
3,Daniela,21.8
4,Felipe,94.9
5,Gustavo,29.5
6,Henrique,95.3
7,Hugo,87.3
8,Isabela,66.0
9,João,26.2
10,Luciana,52.6
11,Marcos,39.4
12,Natália,85.2
13,Sofia,67.5
14,Samuel,40.1
15,Yasmin,97.7
'''), header=None)
# Out:
#        0         1     2
# 0   num       nome  nota
# 1      1       Ana  11.2
# 2      2     Bruno  20.3
# 3      3   Daniela  21.8
# 4      4    Felipe  94.9
# 5      5   Gustavo  29.5
# 6      6  Henrique  95.3
# 7      7      Hugo  87.3
# 8      8   Isabela  66.0
# 9      9      João  26.2
# 10    10   Luciana  52.6
# 11    11    Marcos  39.4
# 12    12   Natália  85.2
# 13    13     Sofia  67.5
# 14    14    Samuel  40.1
# 15    15    Yasmin  97.7

# %%
import pandas as pd

# %%
import io
import pandas as pd

df = pd.read_csv(io.StringIO(data))
display(df.head())
display(df.describe())
# Out:
#    num      nome  nota
# 0     1      Ana  11.2
# 1     2    Bruno  20.3
# 2     3  Daniela  21.8
# 3     4   Felipe  94.9
# 4     5  Gustavo  29.5
#             num        nota
# count  15.000000  15.000000
# mean    8.000000  55.666667
# std     4.472136  30.984896
# min     1.000000  11.200000
# 25%     4.500000  27.850000
# 50%     8.000000  52.600000
# 75%    11.500000  86.250000
# max    15.000000  97.700000

# %%
media = df['nota'].mean()
mediana = df['nota'].median()
desvio = df['nota'].std()

df['desempenho'] = df['nota'].apply(lambda x: 'Acima da média' if x > media else 'Abaixo da média')

# %%
import matplotlib.pyplot as plt

plt.hist(df['nota'], bins=8)
plt.title('Distribuição das Notas - TechGo Solutions')
plt.xlabel('Nota')
plt.ylabel('Frequência')
plt.show()

# %%
import numpy as np

# 2 Simular salários-base entre R$ 3.000 e R$ 8.000
np.random.seed(42)  # garante reprodutibilidade
df['salario_base'] = np.random.randint(3000, 8000, df.shape[0])

# 3 Calcular o percentual de bônus proporcional à nota (máximo 20%)
nota_max = df['nota'].max()

df['bonus_percentual'] = (df['nota'] / nota_max) * 0.20  # escala 0–20%

# 4 Calcular valor do bônus e salário total
df['valor_bonus'] = df['salario_base'] * df['bonus_percentual']
df['salario_total'] = df['salario_base'] + df['valor_bonus']

# 5 Arredondar e ajustar apresentação
df['salario_base'] = df['salario_base'].round(2)
df['valor_bonus'] = df['valor_bonus'].round(2)
df['salario_total'] = df['salario_total'].round(2)
df['bonus_percentual'] = (df['bonus_percentual'] * 100).round(2)  # em %

# 6 Exibir resultado final
print(df[['nome', 'nota', 'salario_base', 'bonus_percentual', 'valor_bonus', 'salario_total']])

# 7 (Opcional) Salvar o novo dataset com bônus incluído
df.to_csv('avaliacao_treinamento_bonus.csv', index=False)
# Out:
#         nome  nota  salario_base  bonus_percentual  valor_bonus  salario_total
# 0        Ana  11.2          3860              2.29        88.50        3948.50
# 1      Bruno  20.3          6772              4.16       281.42        7053.42
# 2    Daniela  21.8          6092              4.46       271.86        6363.86
# 3     Felipe  94.9          3466             19.43       673.33        4139.33
# 4    Gustavo  29.5          7426              6.04       448.45        7874.45
# 5   Henrique  95.3          6444             19.51      1257.14        7701.14
# 6       Hugo  87.3          6171             17.87      1102.82        7273.82
# 7    Isabela  66.0          5919             13.51       799.70        6718.70
# 8       João  26.2          3130              5.36       167.87        3297.87
# 9    Luciana  52.6          4685             10.77       504.46        5189.46
# 10    Marcos  39.4          3769              8.07       303.99        4072.99
# ...
